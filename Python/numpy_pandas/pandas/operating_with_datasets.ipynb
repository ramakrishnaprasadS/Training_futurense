# %% [markdown]
# # working with datasets

# %%
import pandas as pd

# %%
DataFrame1 = pandas.DataFrame({"A" : [1, 3, 4], "B": [5, 9, 12]})
print(DataFrame1)
DataFrame2 = pandas.DataFrame({"empno" : [594,595,596,597],"ename":["ram","hari","nani","novil"],"salary":[70000,50000,90000,70000],"is_experienced":[True,False,False,True]})
print(DataFrame2)
# Out:
#    A   B
# 0  1   5
# 1  3   9
# 2  4  12
#    empno  ename  salary  is_experienced
# 0    594    ram   70000            True
# 1    595   hari   50000           False
# 2    596   nani   90000           False
# 3    597  novil   70000            True

# %% [markdown]
# # reading the datsets

# %%
countries_df = pd.read_csv("C:\\Users\\miles\\Documents\\GitHub\\Training_futurense\\Python\\numpy_pandas\\pandas\\countries of the world.csv")
print(countries_df.head(10))
# Out:
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# ...

# %%
countries_df.isnull()
# Out:
#      Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      False   False       False           False                       False
# 1      False   False       False           False                       False
# 2      False   False       False           False                       False
# 3      False   False       False           False                       False
# 4      False   False       False           False                       False
# ..       ...     ...         ...             ...                         ...
# 222    False   False       False           False                       False
# 223    False   False       False           False                       False
# 224    False   False       False           False                       False
# 225    False   False       False           False                       False
# 226    False   False       False           False                       False
#
# ...

# %%
# The dropna() method removes all rows containing null values:

countries_df.dropna(inplace = True)
print(countries_df)
# Out:
#                 Country                               Region  Population  \
# 0          Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1              Albania   EASTERN EUROPE                          3581655
# 2              Algeria   NORTHERN AFRICA                        32930091
# 6             Anguilla               LATIN AMER. & CARIB           13477
# 7    Antigua & Barbuda               LATIN AMER. & CARIB           69108
# ..                  ...                                  ...         ...
# 218          Venezuela               LATIN AMER. & CARIB        25730435
# 219            Vietnam         ASIA (EX. NEAR EAST)             84402966
# 224              Yemen   NEAR EAST                              21456188
# 225             Zambia   SUB-SAHARAN AFRICA                     11502010
# 226           Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
countries_df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
cnt_new_df=countries_df[['Country','Region']]
print(cnt_new_df)
# Out:
#                 Country                               Region
# 0          Afghanistan         ASIA (EX. NEAR EAST)
# 1              Albania   EASTERN EUROPE
# 2              Algeria   NORTHERN AFRICA
# 6             Anguilla               LATIN AMER. & CARIB
# 7    Antigua & Barbuda               LATIN AMER. & CARIB
# ..                  ...                                  ...
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA
#
# [179 rows x 2 columns]

# %%
cnt_new_df.isnull().sum()
# Out:
# Country    0
# Region     0
# dtype: int64

# %%
cnt_new_df.dtypes
# Out:
# Country    object
# Region     object
# dtype: object

# %%
cnt_new_df.describe()
# Out:
#              Country                               Region
# count            179                                  179
# unique           179                                   11
# top     Afghanistan   SUB-SAHARAN AFRICA
# freq               1                                   47

# %%
# Table of frequency counts for items in a column
cnt_new_df['Region'].value_counts()
# Out:
# SUB-SAHARAN AFRICA                     47
# LATIN AMER. & CARIB                    42
# ASIA (EX. NEAR EAST)                   26
# WESTERN EUROPE                         17
# OCEANIA                                12
# NEAR EAST                              12
# C.W. OF IND. STATES                    10
# EASTERN EUROPE                          6
# NORTHERN AFRICA                         3
# NORTHERN AMERICA                        2
# BALTICS                                 2
# Name: Region, dtype: int64

# %%
from datetime import datetime
updated_at=[]
for i in range(179):
    updated_at.append(datetime.now())
cnt_new_df['updated_at'] = updated_at
#cnt_new_df['updated_at'] = pd.to_datetime(cnt_new_df['updated_at'])
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_18260\3326280244.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cnt_new_df['updated_at'] = updated_at

# %%
for i in range(179):
    cnt_new_df.iloc[i,'updated_at']=datetime.now()
print(cnt_new_df)
# Out:
#                 Country                               Region  \
# 0          Afghanistan         ASIA (EX. NEAR EAST)
# 1              Albania   EASTERN EUROPE
# 2              Algeria   NORTHERN AFRICA
# 6             Anguilla               LATIN AMER. & CARIB
# 7    Antigua & Barbuda               LATIN AMER. & CARIB
# ..                  ...                                  ...
# 153                 NaN                                  NaN
# 169                 NaN                                  NaN
# 171                 NaN                                  NaN
# 174                 NaN                                  NaN
# 177                 NaN                                  NaN
#
#                     updated_at
# 0   2023-01-27 12:40:00.259695
# 1   2023-01-27 12:40:00.267697
# 2   2023-01-27 12:40:00.267697
# 6   2023-01-27 12:40:00.267697
# 7   2023-01-27 12:40:00.267697
# ..                         ...
# 153 2023-01-27 12:40:00.299956
# 169 2023-01-27 12:40:00.299956
# ...

# %%
cnt_new_df.drop(columns=['updated_at'], inplace = True)  
print(cnt_new_df)
# Out:
#                                   Region
# 0          ASIA (EX. NEAR EAST)
# 1    EASTERN EUROPE
# 2    NORTHERN AFRICA
# 6                LATIN AMER. & CARIB
# 7                LATIN AMER. & CARIB
# ..                                   ...
# 153                                  NaN
# 169                                  NaN
# 171                                  NaN
# 174                                  NaN
# 177                                  NaN
#
# [216 rows x 1 columns]

# %%
cnt_new_df.columns
# Out:
# Index(['Country', 'Region', 'updated_at'], dtype='object')

# %%
cnt_new_df.head(5)
# Out:
#               Country                               Region  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
#
#                   updated_at
# 0 2023-01-27 12:40:00.259695
# 1 2023-01-27 12:40:00.267697
# 2 2023-01-27 12:40:00.267697
# 6 2023-01-27 12:40:00.267697
# 7 2023-01-27 12:40:00.267697
