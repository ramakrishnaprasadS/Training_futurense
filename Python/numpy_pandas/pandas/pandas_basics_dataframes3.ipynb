# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\miles\\Downloads\\fortune_data.csv")
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df['Sector'].nunique()
# Out:
# 21

# %%
df['Industry'].nunique()
# Out:
# 73

# %%
sgroup=df.groupby('Sector')

# %%
sgroup.groups
# Out:
# {'Aerospace & Defense': [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], 'Apparel': [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], 'Business Services': [143, 185, 198, 203, 220, 247, 248, 293, 306, 311, 354, 391, 403, 439, 466, 467, 480, 484, 491, 502, 544, 625, 634, 651, 676, 693, 713, 728, 733, 734, 736, 743, 766, 775, 776, 782, 790, 791, 795, 800, 802, 815, 818, 819, 868, 869, 885, 938, 950, 951, 992], 'Chemicals': [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864, 897, 933, 948], 'Energy': [1, 13, 29, 31, 41, 64, 89, 94, 97, 103, 114, 116, 120, 161, 162, 164, 165, 174, 177, 187, 189, 191, 192, 197, 213, 215, 216, 222, 224, 228, 242, 245, 246, 256, 271, 273, 278, 288, 318, 321, 323, 342, 347, 348, 349, 362, 363, 383, 386, 387, 393, 401, 402, 409, 424, 436, 437, 444, 457, 474, 482, 492, 506, 521, 540, 547, 555, 557, 568, 5
# ...

# %%
sgroup.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
len(sgroup)
# Out:
# 21

# %%
sgroup.value_counts()
# Out:
# Sector               Rank  Company              Industry                                       Location          Revenue  Profits  Employees
# Aerospace & Defense  24    Boeing               Aerospace and Defense                          Chicago, IL       96114     5176    161400       1
#                      60    Lockheed Martin      Aerospace and Defense                          Bethesda, MD      46132     3605    126000       1
#                      88    General Dynamics     Aerospace and Defense                          Falls Church, VA  31469     2965    99900        1
#                      118   Northrop Grumman     Aerospace and Defense                          Falls Church, VA  23526     1990    65000        1
#                      120   Raytheon             Aerospace and Defense                          Waltham, MA       23247     2074    61000        1
# ...

# %%
df['Rank'].nunique()
# Out:
# 996

# %%
sgroup.get_group("Media")
# Out:
#      Rank                       Company Sector              Industry  \
# 52     53                        Disney  Media         Entertainment
# 95     96      Twenty-First Century Fox  Media         Entertainment
# 98     99                   Time Warner  Media         Entertainment
# 202   203                           CBS  Media         Entertainment
# 212   213                        Viacom  Media         Entertainment
# 254   255         R.R. Donnelley & Sons  Media  Publishing, Printing
# 326   327                    News Corp.  Media  Publishing, Printing
# 365   366     Live Nation Entertainment  Media         Entertainment
# 405   406      Discovery Communications  Media         Entertainment
# 413   414                   iHeartMedia  Media         Entertainment
# 524   525                 Liberty Media  Media         Entertainment
# 529   530                 Quad/Graphics  Media  Publishing, Printing
# 680   681                         TEGNA  Media         Entertainment
# ...

# %%
sgroup.first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %%
# now from the dataframe findout the max profit done by Energy Sector
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df[df['Sector']=='Energy']['Profits'].max()
# Out:
# 16150

# %%
df2 = df.groupby("Sector").get_group("Energy")
df2[df2['Profits'] == df2['Profits'].max()]
# Out:
#    Rank      Company  Sector            Industry    Location  Revenue  \
# 1     2  Exxon Mobil  Energy  Petroleum Refining  Irving, TX   246204
#
#    Profits  Employees
# 1    16150      75600

# %%
# what is average employees we have for advertising,market industry
df['Industry'].value_counts()
# Out:
# Specialty Retailers: Other                  42
# Utilities: Gas and Electric                 41
# Chemicals                                   30
# Commercial Banks                            28
# Insurance: Property and Casualty (Stock)    28
#                                             ..
# Temporary Help                               5
# Computer Peripherals                         4
# Education                                    3
# Mail, Package, and Freight Delivery          2
# Advertising, marketing                       2
# Name: Industry, Length: 73, dtype: int64

# %%
df[df['Industry']=='Advertising, marketing']
# Out:
#      Rank            Company             Sector                Industry  \
# 185   186      Omnicom Group  Business Services  Advertising, marketing
# 354   355  Interpublic Group  Business Services  Advertising, marketing
#
#          Location  Revenue  Profits  Employees
# 185  New York, NY    15134     1094      74900
# 354  New York, NY     7614      455      49200

# %%
df[df['Industry']=='Advertising, marketing']['Employees'].mean()
# Out:
# 62050.0

# %%
ng=df.groupby(['Sector','Industry'])

# %%
ng.groups
# Out:
# {('Aerospace & Defense', 'Aerospace and Defense'): [23, 44, 59, 87, 117, 119, 208, 244, 281, 377, 388, 489, 559, 604, 784, 787, 835, 902, 957, 986], ('Apparel', 'Apparel'): [90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876, 881, 916], ('Business Services', 'Advertising, marketing'): [185, 354], ('Business Services', 'Diversified Outsourcing Services'): [198, 247, 484, 544, 625, 634, 713, 728, 743, 782, 802, 815, 818, 868], ('Business Services', 'Education'): [736, 819, 992], ('Business Services', 'Financial Data Services'): [203, 248, 293, 306, 391, 403, 467, 480, 491, 651, 693, 766, 775, 776, 791, 795, 800, 885, 951], ('Business Services', 'Miscellaneous'): [439, 733, 869], ('Business Services', 'Temporary Help'): [143, 466, 502, 790, 950], ('Business Services', 'Waste Management'): [220, 311, 676, 734, 938], ('Chemicals', 'Chemicals'): [55, 100, 181, 188, 205, 252, 261, 276, 287, 295, 315, 537, 548, 554, 565, 579, 612, 623, 653, 667, 716, 719, 723, 757, 760, 828, 864,
# ...

# %%
ng.get_group(('Energy','Utilities: Gas and Electric'))
# Out:
#      Rank                          Company  Sector  \
# 94     95                           Exelon  Energy
# 114   115                      Duke Energy  Energy
# 161   162                         Southern  Energy
# 162   163                   NextEra Energy  Energy
# 164   165          American Electric Power  Energy
# 165   166                       PG&E Corp.  Energy
# 187   188                      FirstEnergy  Energy
# 189   190                              AES  Energy
# 228   229              Consolidated Edison  Energy
# 242   243               Dominion Resources  Energy
# 245   246             Edison International  Energy
# 246   247                          Entergy  Energy
# 256   257                      Xcel Energy  Energy
# 271   272  Public Service Enterprise Group  Energy
# 273   274                       DTE Energy  Energy
# 278   279                    Sempra Energy  Energy
# 342   343                Eversource Energy  Energy
# ...

# %%
ng.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
ng['Profits'].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            1437.100000
# Apparel              Apparel                                           549.066667
# Business Services    Advertising, marketing                            774.500000
#                      Diversified Outsourcing Services                  307.500000
#                      Education                                          23.000000
#                                                                          ...
# Transportation       Trucking, Truck Leasing                           212.222222
# Wholesalers          Miscellaneous                                      17.000000
#                      Wholesalers: Diversified                          207.720000
#                      Wholesalers: Electronics and Office Equipment     232.125000
#                      Wholesalers: Food and Grocery                     194.333333
# Name: Profits, Length: 79, dtype: float64

# %%
ng['Profits'].mean().max()
# Out:
# 8347.57142857143

# %%
ng.agg({'Revenue':'sum','Profits':'mean'})
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
df1=pd.read_csv("C:\\Users\\miles\\Downloads\\fortune_data.csv")
df1
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df2=df1.copy()

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df3=pd.concat([df1,df2])

# %%
df3[df3['Company']=="Walmart"]
# Out:
#    Rank  Company     Sector               Industry         Location  Revenue  \
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
#
#    Profits  Employees
# 0    14694    2300000
# 0    14694    2300000

# %%
df3=pd.concat([df1,df2],ignore_index=True)

# %%
df3[df3['Company']=="Walmart"]
# Out:
#       Rank  Company     Sector               Industry         Location  \
# 0        1  Walmart  Retailing  General Merchandisers  Bentonville, AR
# 1000     1  Walmart  Retailing  General Merchandisers  Bentonville, AR
#
#       Revenue  Profits  Employees
# 0      482130    14694    2300000
# 1000   482130    14694    2300000

# %%
df1.merge(df2)
# Out:
#       Rank                    Company                        Sector  \
# 0        1                    Walmart                     Retailing
# 1        2                Exxon Mobil                        Energy
# 2        3                      Apple                    Technology
# 3        4         Berkshire Hathaway                    Financials
# 4        5                   McKesson                   Health Care
# ...    ...                        ...                           ...
# 1003   997  Portland General Electric                        Energy
# 1004   997  Portland General Electric                        Energy
# 1005   997  Portland General Electric                        Energy
# 1006   999                    Wendy’s  Hotels, Resturants & Leisure
# 1007  1000          Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df4=df1.merge(df2)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1008 entries, 0 to 1007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1008 non-null   int64
#  1   Company    1008 non-null   object
#  2   Sector     1008 non-null   object
#  3   Industry   1008 non-null   object
#  4   Location   1008 non-null   object
#  5   Revenue    1008 non-null   int64
#  6   Profits    1008 non-null   int64
#  7   Employees  1008 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 70.9+ KB

# %%
df4[df4['Company']=="Walmart"]
# Out:
#    Rank  Company     Sector               Industry         Location  Revenue  \
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
#
#    Profits  Employees
# 0    14694    2300000

# %%
df5=df1.append(df2)
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_36992\4265038598.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5=df1.append(df2)

# %%
df5[df5['Company']=="Walmart"]
# Out:
#    Rank  Company     Sector               Industry         Location  Revenue  \
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
#
#    Profits  Employees
# 0    14694    2300000
# 0    14694    2300000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
# read df movies,ratings ...convert dtypes similar to movies.csv ...perform a inner join between both df s to extract userid,movieid and movie name

# %%
mdf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\movies.csv')
rdf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\ratings.csv')

# %%
mdf.head(3).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  3 non-null      int64
#  1   title    3 non-null      object
#  2   genres   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
rdf.head(3).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3 non-null      int64
#  1   movieId    3 non-null      int64
#  2   rating     3 non-null      float64
#  3   timestamp  3 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 224.0 bytes

# %%
odf=mdf.merge(rdf,how="inner",on='movieId')

# %%
odf.head(3)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946

# %%
odf=odf.rename({'movieId':'movie_Id'})

# %%
odf.head(3)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946

# %%
odf=odf[['userId','movieId','title','rating']]

# %%
odf
# Out:
#         userId  movieId                                      title  rating
# 0            1        1                           Toy Story (1995)     4.0
# 1            5        1                           Toy Story (1995)     4.0
# 2            7        1                           Toy Story (1995)     4.5
# 3           15        1                           Toy Story (1995)     2.5
# 4           17        1                           Toy Story (1995)     4.5
# ...        ...      ...                                        ...     ...
# 100831     184   193581  Black Butler: Book of the Atlantic (2017)     4.0
# 100832     184   193583               No Game No Life: Zero (2017)     3.5
# 100833     184   193585                               Flint (2017)     3.5
# 100834     184   193587        Bungo Stray Dogs: Dead Apple (2018)     3.5
# 100835     331   193609        Andrew Dice Clay: Dice Rules (1991)     4.0
#
# [100836 rows x 4 columns]

# %%
odf=odf.rename(columns={'movieId':'movie_Id'})

# %%
odf
# Out:
#         userId  movie_Id                                      title  rating
# 0            1         1                           Toy Story (1995)     4.0
# 1            5         1                           Toy Story (1995)     4.0
# 2            7         1                           Toy Story (1995)     4.5
# 3           15         1                           Toy Story (1995)     2.5
# 4           17         1                           Toy Story (1995)     4.5
# ...        ...       ...                                        ...     ...
# 100831     184    193581  Black Butler: Book of the Atlantic (2017)     4.0
# 100832     184    193583               No Game No Life: Zero (2017)     3.5
# 100833     184    193585                               Flint (2017)     3.5
# 100834     184    193587        Bungo Stray Dogs: Dead Apple (2018)     3.5
# 100835     331    193609        Andrew Dice Clay: Dice Rules (1991)     4.0
#
# [100836 rows x 4 columns]

# %%
mdf=mdf.rename(columns={'movieId':'movie_Id'})

# %%
lrdf=mdf.merge(rdf,left_on='movie_Id',right_on='movieId',how="inner")

# %%
lrdf
# Out:
#         movie_Id                                      title  \
# 0              1                           Toy Story (1995)
# 1              1                           Toy Story (1995)
# 2              1                           Toy Story (1995)
# 3              1                           Toy Story (1995)
# 4              1                           Toy Story (1995)
# ...          ...                                        ...
# 100831    193581  Black Butler: Book of the Atlantic (2017)
# 100832    193583               No Game No Life: Zero (2017)
# 100833    193585                               Flint (2017)
# 100834    193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835    193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  movieId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1        1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5        1     4.0
# ...

# %%
lrdf=lrdf[['movie_Id','title','userId','rating']]

# %%
lrdf
# Out:
#         movie_Id                                      title  userId  rating
# 0              1                           Toy Story (1995)       1     4.0
# 1              1                           Toy Story (1995)       5     4.0
# 2              1                           Toy Story (1995)       7     4.5
# 3              1                           Toy Story (1995)      15     2.5
# 4              1                           Toy Story (1995)      17     4.5
# ...          ...                                        ...     ...     ...
# 100831    193581  Black Butler: Book of the Atlantic (2017)     184     4.0
# 100832    193583               No Game No Life: Zero (2017)     184     3.5
# 100833    193585                               Flint (2017)     184     3.5
# 100834    193587        Bungo Stray Dogs: Dead Apple (2018)     184     3.5
# 100835    193609        Andrew Dice Clay: Dice Rules (1991)     331     4.0
#
# [100836 rows x 4 columns]

# %%
# movie---tag---which usr given

mdf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\movies.csv')
rdf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\ratings.csv')
ldf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\links.csv')
tdf=pd.read_csv('C:\\Users\\miles\\Downloads\\ml-latest-small\\tags.csv')

# %%
mdf.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
rdf.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
ldf.head(2)
# Out:
#    movieId  imdbId  tmdbId
# 0        1  114709   862.0
# 1        2  113497  8844.0

# %%
tdf.head(2)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996

# %%
mtdf=mdf.merge(tdf,on='movieId',how='left')[['movieId','userId','tag']]

# %%
mtdf.head(2)
# Out:
#    movieId  userId    tag
# 0        1   336.0  pixar
# 1        1   474.0  pixar

# %%
rtdf=rdf.merge(tdf,how="outer",on='movieId',suffixes=['A','B'])[['userIdA','timestampA','movieId','rating','tag']]

# %%
rtdf.head(2)
# Out:
#    userIdA   timestampA  movieId  rating    tag
# 0      1.0  964982703.0        1     4.0  pixar
# 1      1.0  964982703.0        1     4.0  pixar

# %% [markdown]
# # Time Series

# %%
import datetime as dt

# %%
dt1=dt.datetime(2011,9,21)

# %%
str(dt.datetime(2011,9,21))
# Out:
# '2011-09-21 00:00:00'

# %%
dt1.year
# Out:
# 2011

# %%
dt1.month
# Out:
# 9

# %%
dt1.day
# Out:
# 21

# %%
t1=pd.Timestamp('2023-02-12')
t1
# Out:
# Timestamp('2023-02-12 00:00:00')

# %%
t1=pd.Timestamp('2023/Feb/12')
t1
# Out:
# Timestamp('2023-02-12 00:00:00')

# %%
pd.date_range(start="2023-02-05",end="2023-03-01")
# Out:
# DatetimeIndex(['2023-02-05', '2023-02-06', '2023-02-07', '2023-02-08',
#                '2023-02-09', '2023-02-10', '2023-02-11', '2023-02-12',
#                '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-18', '2023-02-19', '2023-02-20',
#                '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24',
#                '2023-02-25', '2023-02-26', '2023-02-27', '2023-02-28',
#                '2023-03-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2023-02-05",end="2023-03-01",freq='H')
# Out:
# DatetimeIndex(['2023-02-05 00:00:00', '2023-02-05 01:00:00',
#                '2023-02-05 02:00:00', '2023-02-05 03:00:00',
#                '2023-02-05 04:00:00', '2023-02-05 05:00:00',
#                '2023-02-05 06:00:00', '2023-02-05 07:00:00',
#                '2023-02-05 08:00:00', '2023-02-05 09:00:00',
#                ...
#                '2023-02-28 15:00:00', '2023-02-28 16:00:00',
#                '2023-02-28 17:00:00', '2023-02-28 18:00:00',
#                '2023-02-28 19:00:00', '2023-02-28 20:00:00',
#                '2023-02-28 21:00:00', '2023-02-28 22:00:00',
#                '2023-02-28 23:00:00', '2023-03-01 00:00:00'],
#               dtype='datetime64[ns]', length=577, freq='H')

# %%
pd.date_range(start="2023-02-05",end="2023-03-01",freq='3D')
# Out:
# DatetimeIndex(['2023-02-05', '2023-02-08', '2023-02-11', '2023-02-14',
#                '2023-02-17', '2023-02-20', '2023-02-23', '2023-02-26',
#                '2023-03-01'],
#               dtype='datetime64[ns]', freq='3D')

# %%
len(pd.date_range(start="2021-07-26",end="2023-02-02",freq='B'))/30
# Out:
# 13.3

# %%
ds=pd.date_range(start="2021-07-26",end="2023-02-02",freq='B')

# %%
ds=pd.Series(ds)

# %%
ds.dt.day_of_week
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 394    4
# 395    0
# 396    1
# 397    2
# 398    3
# Length: 399, dtype: int64

# %%
pip install pandas_datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------ 109.5/109.5 kB 793.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.8/3.8 MB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.8/62.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.0/96.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# ...
#      -------------------------------------- 140.6/140.6 kB 4.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 155.3/155.3 kB 4.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\miles\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas_datareader as data

# %%
stocks=data.DataReader(name="MSFT",data_source="stooq",start="2022-01-01",end="2023-03-01")

# %%
stocks
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2023-02-01  248.000  255.180  245.470  252.750  3.125991e+07
# 2023-01-31  243.450  247.950  242.945  247.810  2.654107e+07
# 2023-01-30  244.510  245.600  242.200  242.710  2.586736e+07
# 2023-01-27  248.990  249.830  246.830  248.160  2.649894e+07
# 2023-01-26  243.650  248.310  242.000  248.000  3.345449e+07
# ...             ...      ...      ...      ...           ...
# 2022-01-07  311.233  313.565  307.211  311.123  3.302661e+07
# 2022-01-06  310.240  315.739  308.601  310.964  4.001764e+07
# 2022-01-05  322.837  323.046  313.049  313.446  4.042964e+07
# 2022-01-04  331.723  332.090  323.095  325.954  3.298047e+07
# 2022-01-03  332.239  334.859  326.719  331.643  2.918898e+07
#
# [272 rows x 5 columns]

# %%
# find out the total amount of volume of shares that has been trade from Monday to Wednesday
# get th highest value of this stock which has been placed in each year
# find the minimum closing value of the stocks in each quarter in the year 2022
# using dataoffset add particular n days to date column

# %%
t1=pd.Timestamp("2023-02-02")
t2=pd.Timestamp("2023-02-03")

# %%
t1-t2
# Out:
# Timedelta('-1 days +00:00:00')
