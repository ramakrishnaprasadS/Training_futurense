# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\miles\\Downloads\\EmployeesInfo.csv")
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# gathering all columns along with values in a single row
pd.melt(df).
# Out:
#         variable                 value
# 0     First Name               Douglas
# 1     First Name                Thomas
# 2     First Name                 Maria
# 3     First Name                 Jerry
# 4     First Name                 Larry
# ...          ...                   ...
# 7995        Team          Distribution
# 7996        Team               Finance
# 7997        Team               Product
# 7998        Team  Business Development
# 7999        Team                 Sales
#
# [8000 rows x 2 columns]

# %%
df['First Name'].dropna(inplace=True)

# %%
df=df[~df['First Name'].duplicated(keep='first')]

# %%
df.pivot(index="First Name",columns='Team' ,values="First Name")
# Out:
# Team        NaN Business Development Client Services Distribution Engineering  \
# First Name
# NaN         NaN                  NaN             NaN          NaN         NaN
# Aaron       NaN                  NaN             NaN          NaN         NaN
# Adam        NaN                  NaN             NaN         Adam         NaN
# Alan        NaN                  NaN             NaN          NaN         NaN
# Albert      NaN                  NaN             NaN          NaN      Albert
# ...         ...                  ...             ...          ...         ...
# Walter      NaN                  NaN             NaN          NaN         NaN
# Wanda       NaN                  NaN             NaN          NaN         NaN
# Wayne       NaN                  NaN             NaN        Wayne         NaN
# William     NaN                  NaN             NaN          NaN         NaN
# Willie      NaN                  NaN             NaN          NaN         NaN
#
# ...

# %%
import pandas as pd
df1=pd.read_csv("C:\\Users\\miles\\Downloads\\NbaInfo.csv")
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1['Height']=df1['Height'].str.replace('-','.').astype(float)

# %%
df1[(df1['Height']>6.2) & (df1['Position']=='PF')]
# Out:
#                          Name                    Team  Number Position   Age  \
# 5                Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6               Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 29             Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# 31               Lou Amundson         New York Knicks    17.0       PF  33.0
# 40         Kristaps Porzingis         New York Knicks     6.0       PF  20.0
# 44           Derrick Williams         New York Knicks    23.0       PF  25.0
# 46                Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 52                Carl Landry      Philadelphia 76ers     7.0       PF  32.0
# 65              James Johnson         Toronto Raptors     3.0       PF  29.0
# 69          Patrick Patterson         Toronto Raptors    54.0       PF  27.0
# 72                 Luis Scola         Toronto Raptors     4.0       PF  36.0
# ...

# %%
df1.duplicated(subset=['Name'])
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
~df1.duplicated(subset=['Name'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 453    True
# 454    True
# 455    True
# 456    True
# 457    True
# Length: 458, dtype: bool

# %%
df1[~df1.duplicated(subset=['Name'])]
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0     6.2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0     6.6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0     6.5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0     6.5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0     6.1   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0     6.3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0     6.1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0     7.3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0     7.0   231.0
# 457            NaN             NaN     NaN      NaN   NaN     NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1.set_index('Name').sort_index()
# Out:
#                                   Team  Number Position   Age  Height  Weight  \
# Name
# Aaron Brooks             Chicago Bulls     0.0       PG  31.0    6.00   161.0
# Aaron Gordon             Orlando Magic     0.0       PF  20.0    6.90   220.0
# Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6.60   210.0
# Adreian Payne   Minnesota Timberwolves    33.0       PF  25.0    6.10   237.0
# Al Horford               Atlanta Hawks    15.0        C  30.0    6.10   245.0
# ...                                ...     ...      ...   ...     ...     ...
# Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6.30   180.0
# Zach LaVine     Minnesota Timberwolves     8.0       PG  21.0    6.50   189.0
# Zach Randolph        Memphis Grizzlies    50.0       PF  34.0    6.90   260.0
# Zaza Pachulia         Dallas Mavericks    27.0        C  32.0    6.11   275.0
# NaN                                NaN     NaN      NaN   NaN     NaN     NaN
#
# ...
