# %%
pip install boto3
# Out:
# ...
#      ---------------------------------------- 0.0/135.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/135.6 kB ? eta -:--:--
#      --------- ------------------------------ 30.7/135.6 kB ? eta -:--:--
#      --------- ------------------------------ 30.7/135.6 kB ? eta -:--:--
#      ----------- ------------------------- 41.0/135.6 kB 281.8 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/135.6 kB 438.1 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/135.6 kB 438.1 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/135.6 kB 438.1 kB/s eta 0:00:01
#      ------------------------------------ 135.6/135.6 kB 401.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.6 MB ? eta -:--:--
# ...

# %%
import boto3

# %%
s3_client=boto3.client('s3')
